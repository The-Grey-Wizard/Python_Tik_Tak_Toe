# %%
#TODO
#Print a tik-tak-toe board
#Take in player input
#Place the input on the board
#Check if the game is won, tied, lost or ongoing
#Repeat 3 and 4 until the game has been won or tied
#Give players option to play again
from IPython.display import clear_output

# %%
def DisplayBoard(board):
    print(board[6]+"|"+board[7]+""+"|"+board[8])
    print("_____")
    print(board[3]+"|"+board[4]+""+"|"+board[5])
    print("_____")
    print(board[0]+"|"+board[1]+""+"|"+board[2])

# %%
test_board = ["X","O","X","O","X","O","X","O","X"]
blank_board = [" "," "," "," "," "," "," "," "," "]
DisplayBoard(blank_board)
# Out:
#  | |
# _____
#  | |
# _____
#  | |

# %%
def Player_1_Input():
    player_move = input("Press a key on the numpad to make a move: ")
    
    while player_move != "Q":
        
        if player_move not in "1,2,3,4,5,6,7,8,9":
            clear_output()
            print("Error, incorrect selection, please try again. You must select a number on the numpad that coorisponds with the location on the board: ")
            Player_1_Input()
    
        elif player_move == "1":
            if blank_board[0] != " ":
                clear_output()
                DisplayBoard(blank_board)
                print("That spot is already taken, please make a different selection: ")
                Player_1_Input()
                break
            else:
                blank_board[0] = "X"
                DisplayBoard(blank_board)
                break


        elif player_move == "2":
            if blank_board[1] != " ":
                clear_output()
                DisplayBoard(blank_board)
                print("That spot is already taken, please make a different selection: ")
                Player_1_Input()
                break
            else:
                blank_board[1] = "X"
                DisplayBoard(blank_board)
                break

        elif player_move == "3":
            if blank_board[2] != " ":
                clear_output()
                DisplayBoard(blank_board)
                print("That spot is already taken, please make a different selection: ")
                Player_1_Input()
                break
            else:
                blank_board[2] = "X"
                DisplayBoard(blank_board)
                break

        elif player_move == "4":
            if blank_board[3] != " ":
                clear_output()
                DisplayBoard(blank_board)
                print("That spot is already taken, please make a different selection: ")
                Player_1_Input()
                break
            else:
                blank_board[3] = "X"
                DisplayBoard(blank_board)
                break

        elif player_move == "5":
            if blank_board[4] != " ":
                clear_output()
                DisplayBoard(blank_board)
                print("That spot is already taken, please make a different selection: ")
                Player_1_Input()
                break
            else:
                blank_board[4] = "X"
                DisplayBoard(blank_board)
                break

        elif player_move == "6":
            if blank_board[5] != " ":
                clear_output()
                DisplayBoard(blank_board)
                print("That spot is already taken, please make a different selection: ")
                Player_1_Input()
                break
            else:
                blank_board[5] = "X"
                DisplayBoard(blank_board)
                break

        elif player_move == "7":
            if blank_board[6] != " ":
                clear_output()
                DisplayBoard(blank_board)
                print("That spot is already taken, please make a different selection: ")
                Player_1_Input()
                break
            else:
                blank_board[6] = "X"
                DisplayBoard(blank_board)
                break

        elif player_move == "8":
            if blank_board[7] != " ":
                clear_output()
                DisplayBoard(blank_board)
                print("That spot is already taken, please make a different selection: ")
                Player_1_Input()
                break
            else:
                blank_board[7] = "X"
                DisplayBoard(blank_board)
                break

        elif player_move == "9":
            if blank_board[8] != " ":
                clear_output()
                DisplayBoard(blank_board)
                print("That spot is already taken, please make a different selection: ")
                Player_1_Input()
                break
            else:
                blank_board[8] = "X"
                DisplayBoard(blank_board)
                break
    clear_output()
    DisplayBoard(blank_board)

# %%
def Player_2_Input():
    player_move = input("Press a key on the numpad to make a move: ")
    
    while player_move != "Q":
        
        if player_move not in "1,2,3,4,5,6,7,8,9":
            clear_output()
            print("Error, incorrect selection, please try again. You must select a number on the numpad that coorisponds with the location on the board: ")
            Player_2_Input()
    
        elif player_move == "1":
            if blank_board[0] != " ":
                clear_output()
                DisplayBoard(blank_board)
                print("That spot is already taken, please make a different selection: ")
                Player_2_Input()
                break
            else:
                blank_board[0] = "O"
                DisplayBoard(blank_board)
                break


        elif player_move == "2":
            if blank_board[1] != " ":
                clear_output()
                DisplayBoard(blank_board)
                print("That spot is already taken, please make a different selection: ")
                Player_2_Input()
                break
            else:
                blank_board[1] = "O"
                DisplayBoard(blank_board)
                break

        elif player_move == "3":
            if blank_board[2] != " ":
                clear_output()
                DisplayBoard(blank_board)
                print("That spot is already taken, please make a different selection: ")
                Player_2_Input()
                break
            else:
                blank_board[2] = "O"
                DisplayBoard(blank_board)
                break

        elif player_move == "4":
            if blank_board[3] != " ":
                clear_output()
                DisplayBoard(blank_board)
                print("That spot is already taken, please make a different selection: ")
                Player_2_Input()
                break
            else:
                blank_board[3] = "O"
                DisplayBoard(blank_board)
                break

        elif player_move == "5":
            if blank_board[4] != " ":
                clear_output()
                DisplayBoard(blank_board)
                print("That spot is already taken, please make a different selection: ")
                Player_2_Input()
                break
            else:
                blank_board[4] = "O"
                DisplayBoard(blank_board)
                break

        elif player_move == "6":
            if blank_board[5] != " ":
                clear_output()
                DisplayBoard(blank_board)
                print("That spot is already taken, please make a different selection: ")
                Player_2_Input()
                break
            else:
                blank_board[5] = "O"
                DisplayBoard(blank_board)
                break

        elif player_move == "7":
            if blank_board[6] != " ":
                clear_output()
                DisplayBoard(blank_board)
                print("That spot is already taken, please make a different selection: ")
                Player_2_Input()
                break
            else:
                blank_board[6] = "O"
                DisplayBoard(blank_board)
                break

        elif player_move == "8":
            if blank_board[7] != " ":
                clear_output()
                DisplayBoard(blank_board)
                print("That spot is already taken, please make a different selection: ")
                Player_2_Input()
                break
            else:
                blank_board[7] = "O"
                DisplayBoard(blank_board)
                break

        elif player_move == "9":
            if blank_board[8] != " ":
                clear_output()
                DisplayBoard(blank_board)
                print("That spot is already taken, please make a different selection: ")
                Player_2_Input()
                break
            else:
                blank_board[8] = "O"
                DisplayBoard(blank_board)
                break
    clear_output()
    DisplayBoard(blank_board)

# %%
def Begin_Play():
    while True:
        Player_1_Input()
        Player_2_Input()
        if Player_1_Input(player_move) == "Q":
            break

# %%
Begin_Play()
# Out:
#  | |
# _____
#  | |
# _____
# X|O|X

# %%
Player_1_Input()

# %%
def Mark_Move():
    pass

# %%
def Check_Game_State():
    #who won?
    #who lost?
    #is tied?
    #is still running
    pass

# %%
def PlayAgain():
    play_again = input("Would you like to play again? (Y/N): ")
